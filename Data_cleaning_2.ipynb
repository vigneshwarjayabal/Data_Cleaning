# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshwarjayabal/Data_Cleaning/blob/main/Data_cleaning_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**kurtosis ,skewness**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import plotly.express as px

# %%
df=pd.read_csv('/content/drive/MyDrive/Wine_Quality_Data.csv')

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
sns.distplot(df["pH"])
# Out:
# <ipython-input-5-ff66c9686195>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["pH"])
# <Axes: xlabel='pH', ylabel='Density'>

# %%
df['color'].unique()
# Out:
# array(['red', 'white'], dtype=object)

# %%
df['color'] = df['color'].map({'red':1,'white':2})

# %%
for i in df.columns:
  print(i,df[i].skew())
# Out:
# fixed_acidity 1.7232896467669239
# volatile_acidity 1.4950965423685545
# citric_acid 0.4717306724886708
# residual_sugar 1.4354042627889907
# chlorides 5.3998277319699035
# free_sulfur_dioxide 1.2200660740665203
# total_sulfur_dioxide -0.0011774782344379131
# density 0.5036017301419995
# pH 0.38683879806082694
# sulphates 1.7972700037785152
# alcohol 0.565717729098518
# quality 0.18962269337269683
# color -1.1790954931481004

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import scipy.stats as stats

# Sample data
data = [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 8, 9, 9, 9, 10]

# Calculate Skewness
skewness = stats.skew(data)

# Calculate Kurtosis
kurtosis = stats.kurtosis(data)

# Print results
print(f"Skewness: {skewness:.2f}")
print(f"Kurtosis: {kurtosis:.2f}")
# Out:
# Skewness: -0.05
# Kurtosis: -1.26

# %%
for i in df.columns:
  print(i,df[i].kurtosis())
# Out:
# fixed_acidity 5.061160665014649
# volatile_acidity 2.8253724172310117
# citric_acid 2.3972392160392233
# residual_sugar 4.359271947703975
# chlorides 50.89805146078061
# free_sulfur_dioxide 7.906238067451564
# total_sulfur_dioxide -0.3716636548571346
# density 6.606066990876695
# pH 0.3676572673539491
# sulphates 8.65369882261069
# alcohol -0.5316873828760138
# quality 0.2323222693432636
# color -0.609921667684866

# %%
#step1 - identity df["column"].skew()     high flow in x
#case1 - output in between -0.5 to 0.5 - less skewness so no need to transform that column
#case2 - output in between -1 to -0.5 or 0.5 to 1 - moderately skewed transform the column can be considered
#case3 - output >1 or <-1 - highly skewed so need to transform the data.(note: count of data is greater it must to considered else it can be consider)

#step2 - identity kurtosis(df["column"])  high flow in y
#case1 - output in between -3 to 3 - less kurtosis so no need to transform that column
#case2 - output in between -6 to -3 or 3 to 6 - moderately kurtosis transform the column can be considered
#case3 - output >6 or <-6 - highly kurtosis so need to transform the data.(note: count of data is greater it must to considered else it can be consider)

# %%
df = pd.read_csv('/content/drive/MyDrive/train-chennai-sale.csv')

# %%
df['AREA']=df["AREA"].apply(lambda i:"Anna Nagar" if (i == "Ana Nagar" or i == "Ann Nagar") else i)
df['AREA']=df["AREA"].apply(lambda i:"Karapakkam" if (i == "Karapakam" ) else i)
df['AREA']=df["AREA"].apply(lambda i:"Adyar" if (i == "Adyr") else i)
df['AREA']=df["AREA"].apply(lambda i:"Velachery" if (i == "Velchery") else i)
df['AREA']=df["AREA"].apply(lambda i:"Chrompet" if (i == "Chrompt" or i == "Chrmpet" or i =="Chormpet") else i)
df['AREA']=df["AREA"].apply(lambda i:"KK Nagar" if (i == "KKNagar") else i)
df['AREA']=df["AREA"].apply(lambda i:"T Nagar" if (i == "TNagar") else i)
df['SALE_COND']=df["SALE_COND"].apply(lambda i:"AbNormal" if (i == "Ab Normal") else i)
df['SALE_COND']=df["SALE_COND"].apply(lambda i:"Partial" if (i == "Partiall" or i == "PartiaLl") else i)
df['SALE_COND']=df["SALE_COND"].apply(lambda i:"AdjLand" if (i == "Adj Land") else i)
df['PARK_FACIL']=df["PARK_FACIL"].apply(lambda i:"No" if (i == "Noo") else i)
df['BUILDTYPE']=df["BUILDTYPE"].apply(lambda i:"Commercial" if (i == "Comercial") else i)
df['BUILDTYPE']=df["BUILDTYPE"].apply(lambda i:"Others" if (i == "Other") else i)
df['UTILITY_AVAIL']=df["UTILITY_AVAIL"].apply(lambda i:"No sewage" if (i == "NoSewr " or i == "NoSeWa") else i)  #sewage
df['UTILITY_AVAIL']=df["UTILITY_AVAIL"].apply(lambda i:"AllPub" if (i == "All Pub") else i)
df['STREET']=df['STREET'].apply(lambda i:"Paved" if ( i == "Pavd") else i )
df['STREET']=df['STREET'].apply(lambda i:"No Access" if ( i == "NoAccess") else i )

# %%
df['DATE_SALE']=pd.to_datetime(df["DATE_SALE"],format="%d-%m-%Y")
df['DATE_BUILD']=pd.to_datetime(df["DATE_BUILD"],format="%d-%m-%Y")

# %%
df.set_index("PRT_ID",inplace=True)

# %%
df["PARK_FACIL"]=df["PARK_FACIL"].map({"Yes":1,"No":0})
df
# Out:
#               AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# PRT_ID
# P03210  Karapakkam      1004 2011-05-04            131        1.0         1.0
# P09411  Anna Nagar      1986 2006-12-19             26        2.0         1.0
# P01812       Adyar       909 2012-02-04             70        1.0         1.0
# P05346   Velachery      1855 2010-03-13             14        3.0         2.0
# P06210  Karapakkam      1226 2009-10-05             84        1.0         1.0
# ...            ...       ...        ...            ...        ...         ...
# P03834  Karapakkam       598 2011-01-03             51        1.0         1.0
# P10000   Velachery      1897 2004-04-08             52        3.0         2.0
# P09594   Velachery      1614 2006-08-25            152        2.0         1.0
# P06508  Karapakkam       787 2009-08-03             40        1.0         1.0
# P09794   Velachery      1896 2005-07-13            156        3.0         2.0
#
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

encode=OrdinalEncoder()

for i in df.select_dtypes(include=["object"]).columns:
  df[i]=encode.fit_transform(df[[i]])

# %%
df["year_date_sale"]=df["DATE_SALE"].dt.year
df["month_date_sale"]=df["DATE_SALE"].dt.month
df["day_date_sale"]=df["DATE_SALE"].dt.day
df["week_date_sale"]=df["DATE_SALE"].dt.day_of_week

df["build_age"]=2005-df["DATE_BUILD"].dt.year

# %%
df=df.drop(['DATE_BUILD',"DATE_SALE"],axis=1)

# %%
val_col=["QS_ROOMS","QS_BATHROOM","QS_BEDROOM"]
target_col="QS_OVERALL"
def fill_null_QS_OVERALL(row):
  if pd.isnull(row[target_col]):
    return row[val_col].mean()
  else:
    return row[target_col]

df[target_col]=df.apply(fill_null_QS_OVERALL,axis=1)


df.loc[df["N_BATHROOM"].isnull(),"N_BATHROOM"]=df[df["N_BATHROOM"].isnull()].apply(lambda i: 2 if ((i["N_BEDROOM"] == 1) & (i["INT_SQFT"] >1800)) else 1,axis=1)

df.loc[df["N_BEDROOM"].isnull(),"N_BEDROOM"]=df[df["N_BEDROOM"].isnull()].apply(lambda i: 1 if ((i["N_BATHROOM"] == 1) & (i["INT_SQFT"] <1800)) else 2 ,axis=1)

# %%
for i in df.columns:
  print(i,df[i].kurtosis())
# Out:
# AREA -0.9453032687539187
# INT_SQFT -0.8863792596117048
# DIST_MAINROAD -1.1652403779921705
# N_BEDROOM 0.7350588716351338
# N_BATHROOM -0.0359462695907653
# N_ROOM -0.530786312676168
# SALE_COND -1.3039916400445632
# PARK_FACIL -2.000228238669906
# BUILDTYPE -1.4762884819607178
# UTILITY_AVAIL -1.4226509017054234
# STREET -1.6039328224187268
# MZZONE -0.28201493956431145
# QS_ROOMS -1.1975351234879212
# QS_BATHROOM -1.2162513503852497
# QS_BEDROOM -1.190165264635618
# QS_OVERALL -0.4883834151854103
# REG_FEE 1.1264994119250469
# COMMIS 1.0733633447248279
# SALES_PRICE 0.5881293416070852
# year_date_sale -0.11161936121385185
# month_date_sale -1.2641412364426328
# day_date_sale -1.1863966252802844
# week_date_sale -1.231621267622495
# build_age -0.6867146648420364

# %%
for i in df.columns:
  print(i,df[i].skew())
# Out:
# AREA 0.13343045941757498
# INT_SQFT 0.1312376307506204
# DIST_MAINROAD 0.01814383555951245
# N_BEDROOM 1.1620744779782093
# N_BATHROOM 1.401450649313029
# N_ROOM 0.11880076563010564
# SALE_COND -0.00040880375958725427
# PARK_FACIL -0.01829130298862382
# BUILDTYPE -0.0017946306202598684
# UTILITY_AVAIL -0.5116456260002302
# STREET -0.013865288462961594
# MZZONE -0.7714946652909218
# QS_ROOMS -0.018957043705685576
# QS_BATHROOM 0.0003104318578001027
# QS_BEDROOM 0.017281609064373933
# QS_OVERALL -0.006454301446482952
# REG_FEE 1.0377545610178516
# COMMIS 0.9516562164668685
# SALES_PRICE 0.7733433358864348
# year_date_sale -0.1505916745880421
# month_date_sale -0.0068969400719506085
# day_date_sale 0.05182360024764906
# week_date_sale 0.01296476763463061
# build_age 0.3051026547558558

# %%
from scipy.stats import kurtosis
from scipy.stats import norm
for i in df.columns:                                   #skew -0.5 to 0.5 and kurtosis -3 to 3
  print(i,kurtosis(df[i]),df[i].skew())
  sns.distplot(df[i],fit=norm)
  plt.show()
# Out:
# AREA -0.94548241778896 0.13343045941757498
# <ipython-input-34-7011793057b8>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# INT_SQFT -0.886599843733396 0.1312376307506204
# <ipython-input-34-7011793057b8>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df.columns
# Out:
# Index(['AREA', 'INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM', 'N_BATHROOM',
#        'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'BUILDTYPE', 'UTILITY_AVAIL',
#        'STREET', 'MZZONE', 'QS_ROOMS', 'QS_BATHROOM', 'QS_BEDROOM',
#        'QS_OVERALL', 'REG_FEE', 'COMMIS', 'SALES_PRICE', 'year_date_sale',
#        'month_date_sale', 'day_date_sale', 'week_date_sale', 'build_age'],
#       dtype='object')

# %%
kurtosis(df["SALES_PRICE"])
# Out:
# 0.5868718899581031

# %%
df["SALES_PRICE_NEW"]=np.log(df["SALES_PRICE"])

# %%
df["SALES_PRICE_NEW"]
# Out:
# PRT_ID
# P03210    2.762769
# P09411    2.826937
# P01812    2.796832
# P05346    2.777603
# P06210    2.761138
#             ...
# P03834    2.740399
# P10000    2.784812
# P09594    2.768702
# P06508    2.769860
# P09794    2.779796
# Name: SALES_PRICE_NEW, Length: 7109, dtype: float64

# %%
sns.distplot(df["SALES_PRICE_NEW"],fit=norm)
# Out:
# <ipython-input-45-9ae4bbb00546>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["SALES_PRICE_NEW"],fit=norm)
# <Axes: xlabel='SALES_PRICE_NEW', ylabel='Density'>

# %%
sns.distplot(df["SALES_PRICE"],fit=norm)
# Out:
# <ipython-input-46-1738e7e36211>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["SALES_PRICE"],fit=norm)
# <Axes: xlabel='SALES_PRICE', ylabel='Density'>

# %%
#lmbda = 0 = log(x)

#lmbda = 0.5 = sqrt(x)

#lmbda = -0.5 = 1/sqrt(x)

#lmbda = 1 = x

#lmbda = -1 = 1/x

#lmbda = 2 = x**2

#lmbda = -2 = 1/x**2

# %%
for j in df.columns:
  if df[j].skew() < 0.5 and df[j].skew() > -0.5 and df[j].kurtosis() < 3 and df[j].kurtosis() > -3 :
    continue
  print(j)
# Out:
# N_BEDROOM
# N_BATHROOM
# UTILITY_AVAIL
# MZZONE
# REG_FEE
# COMMIS

# %%
for j in df.columns:
  if df[j].skew() < 0.5 and df[j].skew() > -0.5 and df[j].kurtosis() < 3 and df[j].kurtosis() > -3 :
    continue
  print(j)
  method=[0,0.5,-0.5,1,-1,2,-2]
  for i in method:
     print(i)
     print("skewness",pd.DataFrame(stats.boxcox(df[j],lmbda=i)).skew().values,"kurtosis",pd.DataFrame(stats.boxcox(df[j],lmbda=i)).kurtosis().values)
  print("--------------------------")
# Out:
# N_BEDROOM
# 0
# skewness [0.56472642] kurtosis [-1.04732489]
# 0.5
# skewness [0.81920785] kurtosis [-0.35085338]
# -0.5
# skewness [0.3922583] kurtosis [-1.46366278]
# 1
# skewness [1.16207448] kurtosis [0.73505887]
# -1
# skewness [0.28355571] kurtosis [-1.70071243]
# 2
# skewness [2.03474398] kurtosis [4.2590793]
# -2
# skewness [0.18139384] kurtosis [-1.90225912]
# --------------------------
# N_BATHROOM
# 0
# skewness [1.40145065] kurtosis [-0.03594627]
# 0.5
# skewness [1.40145065] kurtosis [-0.03594627]
# -0.5
# skewness [1.40145065] kurtosis [-0.03594627]
# 1
# skewness [1.40145065] kurtosis [-0.03594627]
# -1
# skewness [1.40145065] kurtosis [-0.03594627]
# 2
# skewness [1.40145065] kurtosis [-0.03594627]
# -2
# skewness [1.40145065] kurtosis [-0.03594627]
# --------------------------
# UTILITY_AVAIL
# 0
# skewness [nan] kurtosis [nan]
# 0.5
# skewness [-0.84031875] kurtosis [-1.06185281]
# -0.5
# skewness [nan] kurtosis [nan]
# 1
# ...

# %%
df2=pd.read_csv("/content/drive/MyDrive/Wine_Quality_Data.csv")

# %%
import plotly.express as px
px.box(df2,y="free_sulfur_dioxide",points="all",x="quality",color="quality")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
q1=df["QS_OVERALL"].quantile(0.25)
q1
# Out:
# 3.13

# %%
q3=df["QS_OVERALL"].quantile(0.75)
q3
# Out:
# 3.89

# %%
diff = q3-q1

# %%
diff
# Out:
# 0.7600000000000002

# %%
upper_fence=q3+1.5*diff
upper_fence
# Out:
# 5.03

# %%
lower_fence=q1-1.5*diff
lower_fence
# Out:
# 1.9899999999999995

# %%
outlier=df[(df["QS_OVERALL"]<lower_fence) | (df["QS_OVERALL"]>upper_fence)]
outlier
# Out:
# Empty DataFrame
# Columns: [AREA, INT_SQFT, DIST_MAINROAD, N_BEDROOM, N_BATHROOM, N_ROOM, SALE_COND, PARK_FACIL, BUILDTYPE, UTILITY_AVAIL, STREET, MZZONE, QS_ROOMS, QS_BATHROOM, QS_BEDROOM, QS_OVERALL, REG_FEE, COMMIS, SALES_PRICE, year_date_sale, month_date_sale, day_date_sale, week_date_sale, build_age, SALES_PRICE_NEW]
# Index: []
#
# [0 rows x 25 columns]

# %%
data=df[(df["QS_OVERALL"]>=lower_fence) & (df["QS_OVERALL"]<=upper_fence)]  # without outlier
data
# Out:
#         AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# PRT_ID
# P03210   4.0      1004            131        1.0         1.0       3
# P09411   1.0      1986             26        2.0         1.0       5
# P01812   0.0       909             70        1.0         1.0       3
# P05346   6.0      1855             14        3.0         2.0       5
# P06210   4.0      1226             84        1.0         1.0       3
# ...      ...       ...            ...        ...         ...     ...
# P03834   4.0       598             51        1.0         1.0       2
# P10000   6.0      1897             52        3.0         2.0       5
# P09594   6.0      1614            152        2.0         1.0       4
# P06508   4.0       787             40        1.0         1.0       2
# P09794   6.0      1896            156        3.0         2.0       5
#
#         SALE_COND  PARK_FACIL  BUILDTYPE  UTILITY_AVAIL  ...  QS_OVERALL  \
# ...

# %% [markdown]
# #**Principal Component Analysis (PCA)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.decomposition import PCA

# %%
pca_obj=PCA(n_components=2)

# %%
enc_data=pca_obj.fit_transform(df2.iloc[:,:8])

# %%
enc_data
# Out:
# array([[-84.11817855,  -0.14078678],
#        [-48.78384736,   5.85007578],
#        [-63.73921207,  -0.87345215],
#        ...,
#        [ -4.90235957,   0.51181228],
#        [ -8.17609759,  -8.97991232],
#        [-19.39718074,  -4.2656956 ]])

# %%
enc_data_df=pd.DataFrame(enc_data,columns=["c1","c2"])
enc_data_df
# Out:
#              c1         c2
# 0    -84.118179  -0.140787
# 1    -48.783847   5.850076
# 2    -63.739212  -0.873452
# 3    -57.485922  -0.342148
# 4    -84.118179  -0.140787
# ...         ...        ...
# 6492 -24.738013  -0.917927
# 6493  57.013287  13.708454
# 6494  -4.902360   0.511812
# 6495  -8.176098  -8.979912
# 6496 -19.397181  -4.265696
#
# [6497 rows x 2 columns]

# %%
rev_data=pca_obj.inverse_transform(enc_data)
rev_data
# Out:
# array([[  7.83925471,   0.43940534,   0.27771205, ...,  11.00031415,
#          33.99900838,   0.99454768],
#        [  7.54537026,   0.39285918,   0.29342977, ...,  24.97144427,
#          66.96394185,   0.99461843],
#        [  7.69220306,   0.415843  ,   0.28781607, ...,  14.98474923,
#          53.98062466,   0.99458271],
#        ...,
#        [  7.2488833 ,   0.34507109,   0.31611935, ...,  29.89321203,
#         110.86014272,   0.99468867],
#        [  7.32400867,   0.35638936,   0.31687999, ...,  19.90646106,
#         109.87412707,   0.99466979],
#        [  7.38187428,   0.3659839 ,   0.31024715, ...,  21.90547744,
#          97.87419366,   0.99465645]])

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Sample data - let's say we have three features: Height, Weight, and Age
data = np.array([[165, 55, 25],
                 [170, 60, 28],
                 [175, 65, 32],
                 [180, 70, 35],
                 [185, 75, 40]])

# Step 1: Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Step 2: Apply PCA
pca = PCA(n_components=2)  # Reduce the data to 2 principal components
principal_components = pca.fit_transform(scaled_data)

# Step 3: Plot the transformed data (2D)
plt.scatter(principal_components[:, 0], principal_components[:, 1])
plt.title('PCA Result')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# Step 4: Output the explained variance
print(f"Explained variance by each component: {pca.explained_variance_ratio_}")
# Out:
# Explained variance by each component: [0.99822551 0.00177449]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Example data: 3 features (Height, Weight, Age)
data = [[165, 55, 25],
        [170, 60, 28],
        [175, 65, 32],
        [180, 70, 35],
        [185, 75, 40]]

# Step 1: Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Step 2: Apply PCA to reduce to 2 dimensions
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)

# Output the transformed data (reduced dimensions)
print(principal_components)
# Out:
# [[-2.40231196e+00  6.52654188e-02]
#  [-1.25605540e+00 -4.51106130e-02]
#  [ 2.22560143e-17  3.15168420e-17]
#  [ 1.14625655e+00 -1.10376032e-01]
#  [ 2.51211081e+00  9.02212259e-02]]

# %% [markdown]
# #**ACID Transactions**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Euclid's Algorithm
#Greatest Common Divisor (GCD)
#Least Common Multiplier(LCM)

import math

math.gcd(8,12)
# Out:
# 4

# %%
math.lcm(8,12)
# Out:
# 24

# %%
a = int(input("Enter your first number: "))
b = int(input("enter your second number: "))
while b>0:
  r = a%b
  a=b
  b=r
GCD = a
print("GCD is", GCD)
# Out:
# Enter your first number: 24
# enter your second number: 16
# GCD is 8

# %%
a = int(input("Enter your first number: "))
b = int(input("enter your second number: "))
t1, t2 = a, b
while b>0:
  r = a%b
  a=b
  b=r
GCD = a
LCM = (t1*t2)/GCD
print("GCD is", GCD)
print("LCM is", LCM)
# Out:
# Enter your first number: 36
# enter your second number: 24
# GCD is 12
# LCM is 72.0

# %%
# REGULAR EXPRESSION
import re
pattern= r"hello"
string="hello shabari"
result=re.match(pattern,string)
if result:
  print("match found")
else:
  print("match not found")
print(result)
# Out:
# match found
# <re.Match object; span=(0, 5), match='hello'>

# %%
pattern= r"shabari"
string="hello shabari"
result=re.match(pattern,string)
if result:
  print("match found")
else:
  print("match not found")
print(result)
# Out:
# match not found
# None

# %%
pattern= r"shabari"
string="hello shabari shabari"
result=re.findall(pattern,string)
if result:
  print("match found")
else:
  print("match not found")
print(result)
# Out:
# match found
# ['shabari', 'shabari']

# %%
pattern = r'^[A-Z]'

# Test strings
strings = ["Hello", "world", "Python", "regular expressions"]

# Check each string
for s in strings:
    if re.match(pattern, s):
        print(f"'{s}' starts with a capital letter.")
    else:
        print(f"'{s}' does NOT start with a capital letter.")
# Out:
# 'Hello' starts with a capital letter.
# 'world' does NOT start with a capital letter.
# 'Python' starts with a capital letter.
# 'regular expressions' does NOT start with a capital letter.

# %%
def validate_password(password):
    pattern = r"^(?=.*[A-Z])(?=.*[0-9])(?=.*[@#$%^&*])[A-Za-z\d@#$%^&*]{8,}$"

    if re.match(pattern, password):
        return "Password is valid"
    else:
        return "Password is invalid"
password = input()
validate_password(password)
# Out:
# #vicky@123Dhoni
# 'Password is valid'
